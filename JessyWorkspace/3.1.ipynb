# %% [markdown]
# ## Start here
# ### loading and cleaning dataset:

# %%
import pandas as pd

# %%
#read in data"
file_path = "C:\\Users\\jessi\\Desktop\\DSML\\Chicago\\Chicago\\"
Chicago_set = pd.read_csv("{}chicago_2016.csv".format(file_path), sep=",", parse_dates=["start_time","end_time"])

# %%
Chicago_set.columns
# Out:
# Index(['start_time', 'end_time', 'start_station_id', 'end_station_id',
#        'start_station_name', 'end_station_name', 'bike_id', 'user_type'],
#       dtype='object')

# %%
Chicago_set.info
# Out:
# <bound method DataFrame.info of                  start_time            end_time  start_station_id  \
# 0       2016-03-31 23:53:00 2016-04-01 00:07:00               344
# 1       2016-03-31 23:46:00 2016-03-31 23:57:00               128
# 2       2016-03-31 23:42:00 2016-03-31 23:46:00               350
# 3       2016-03-31 23:37:00 2016-03-31 23:55:00               303
# 4       2016-03-31 23:33:00 2016-03-31 23:37:00               334
# ...                     ...                 ...               ...
# 3595378 2016-10-01 00:01:08 2016-10-01 00:04:42                56
# 3595379 2016-10-01 00:00:58 2016-10-01 00:09:33               255
# 3595380 2016-10-01 00:00:41 2016-10-01 00:04:19                56
# 3595381 2016-10-01 00:00:32 2016-10-01 00:16:02               298
# 3595382 2016-10-01 00:00:14 2016-10-01 00:16:02               298
#
#          end_station_id              start_station_name  \
# 0                   458   Ravenswood Ave & Lawrence Ave
# ...

# %%
#checking for null values
Chicago_set.isnull()
# Out:
#          start_time  end_time  start_station_id  end_station_id  \
# 0             False     False             False           False
# 1             False     False             False           False
# 2             False     False             False           False
# 3             False     False             False           False
# 4             False     False             False           False
# ...             ...       ...               ...             ...
# 3595378       False     False             False           False
# 3595379       False     False             False           False
# 3595380       False     False             False           False
# 3595381       False     False             False           False
# 3595382       False     False             False           False
#
#          start_station_name  end_station_name  bike_id  user_type
# 0                     False             False    False      False
# ...

# %%
#grouping dataset by stations
end_station_name_groups_mean = Chicago_set.groupby("end_station_name").mean()

# %%
end_station_name_groups_mean
# Out:
#                               start_station_id  end_station_id      bike_id
# end_station_name
# 2112 W Peterson Ave                 422.009862           456.0  2906.205128
# 63rd St Beach                       241.396030           101.0  3057.584121
# 900 W Harrison St                   144.653638           109.0  2887.017623
# Aberdeen St & Jackson Blvd          145.217299            21.0  2954.451306
# Aberdeen St & Monroe St             142.105640            80.0  2886.713587
# ...                                        ...             ...          ...
# Wood St & Taylor St                 129.753641           317.0  2876.044394
# Woodlawn Ave & 55th St              336.361818           248.0  2830.511021
# Woodlawn Ave & 75th St              349.125000           569.0  3034.750000
# Woodlawn Ave & Lake Park Ave        286.551363           413.0  2907.749476
# Yates Blvd & 75th St                372.047059           396.0  3113.529412
#
# [587 rows x 3 columns]

# %% [markdown]
# ### apparently no null values....

# %% [markdown]
# ### Geographical demand patterns:

# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import seaborn as sns
sns.set()
sns.set_style("white")
sns.set_palette("GnBu_d")

import folium
from folium import plugins
from folium.plugins import HeatMap
from datetime import datetime #for working with times objects
from datetime import timedelta #for working with times objects
import math
import random
import timeit

# %%
#import geological data

file_path = "C:\\Users\\jessi\\Desktop\\DSML\\AdditionalDataChicago\\Divvy_Trips_2016_Q1Q2\\Divvy_Trips_2016_Q1Q2\\"
Divvy_Stations_2016_Q1Q2 = pd.read_csv("{}Divvy_Stations_2016_Q1Q2.csv".format(file_path), sep=",")

# %%
Divvy_Stations_2016_Q1Q2.columns
# Out:
# Index(['id', 'name', 'latitude', 'longitude', 'dpcapacity', 'online_date'], dtype='object')

# %%
geo_Divvy_Stations_2016_Q1Q2_mean = Divvy_Stations_2016_Q1Q2.groupby("latitude").mean()

# %%
geo_Divvy_Stations_2016_Q1Q2_mean
# Out:
#             id  longitude  dpcapacity
# latitude
# 41.756971  572 -87.624621          11
# 41.757120  395 -87.575839          15
# 41.757871  398 -87.549386          19
# 41.758308  570 -87.606685          11
# 41.758670  270 -87.586883          15
# ...        ...        ...         ...
# 42.012560  353 -87.674367          15
# 42.032562  597 -87.679101          15
# 42.048214  596 -87.683485          15
# 42.048308  600 -87.698224          15
# 42.063598  601 -87.698730          15
#
# [535 rows x 3 columns]

# %%
Divvy_Stations_2016_Q1Q2.isnull()
# Out:
#         id   name  latitude  longitude  dpcapacity  online_date
# 0    False  False     False      False       False        False
# 1    False  False     False      False       False        False
# 2    False  False     False      False       False        False
# 3    False  False     False      False       False        False
# 4    False  False     False      False       False        False
# ..     ...    ...       ...        ...         ...          ...
# 530  False  False     False      False       False        False
# 531  False  False     False      False       False        False
# 532  False  False     False      False       False        False
# 533  False  False     False      False       False        False
# 534  False  False     False      False       False        False
#
# [535 rows x 6 columns]

# %%
Divvy_Stations_2016_Q1Q2["Coordinates"] = list(zip(Divvy_Stations_2016_Q1Q2["latitude"].round(4),Divvy_Stations_2016_Q1Q2["longitude"].round(4)))

# %%
#plot locations of all bike stations
Divvy_Stations_2016_Q1Q2_heat_map = folium.Map(location=(41.873222041337044, -87.62596070777431),tiles='OpenStreetMap',zoom_start=12, control_scale=True, max_zoom=20)

#add child
Divvy_Stations_2016_Q1Q2_heat_map.add_child(plugins.HeatMap(Divvy_Stations_2016_Q1Q2["Coordinates"], radius=10))
#Divvy_Stations_2016_Q1Q2_heat_map.add_child(plugins.HeatMap(Divvy_Stations_2016_Q1Q2["id"], radius=20))

Divvy_Stations_2016_Q1Q2_heat_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
